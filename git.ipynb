# %% [markdown]
# <a href="https://colab.research.google.com/github/Podushka1337/homework/blob/main/git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1) Инициализация нового локального репозитория - git init

# %% [markdown]
# ![image.png](data:image/png;base64,...)
